# %% [markdown]
# <a href="https://colab.research.google.com/github/jsansao/dlvc/blob/main/Licao9bis_CIFAR_10_CNN_90porcento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lição 9bis (CIFAR-10 com recursos para melhorar overfitting e acurácia)
#
# Para este exercício, vamos usar o dataset CIFAR-10. O CIFAR-10 consiste de 60000 imagens coloridas (32 x 32 pixels) de 10 objetos distintos. O conjunto de treinamento tem 50000 imagens e o conjunto de teste tem 10000.
#
# As classes são:
#
#
# * Avião
# * Automóvel
# * Pássaro
# * Gato
# * Cervo
# * Cão
# * Sapo
# * Cavalo
# * Navio
# * Caminhão

# %% [markdown]
# # Baseline

# %%
import tensorflow as tf



class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.9):
      print("\nAtingiu acc > 0.9, cancelando treinamento")
      self.model.stop_training = True

callbacks = myCallback()

mnist = tf.keras.datasets.cifar10
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images.reshape(50000, 32, 32, 3)
training_images=training_images / 255.0
test_images = test_images.reshape(10000, 32, 32, 3)
test_images=test_images/255.0
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(32, 32, 3)),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')

])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#model.fit(training_images, training_labels, epochs=10, callbacks=[callbacks])

history = model.fit(training_images, training_labels,
                              validation_data=(test_images, test_labels),                              
                              epochs=10,
                              verbose=2)


test_loss, test_acc = model.evaluate(test_images, test_labels)
print(test_acc)
# Out:
# Epoch 1/10
# 1563/1563 - 38s - loss: 1.5311 - accuracy: 0.4416 - val_loss: 1.3815 - val_accuracy: 0.5095
# Epoch 2/10
# 1563/1563 - 8s - loss: 1.1580 - accuracy: 0.5893 - val_loss: 1.0794 - val_accuracy: 0.6139
# Epoch 3/10
# 1563/1563 - 8s - loss: 1.0079 - accuracy: 0.6452 - val_loss: 0.9740 - val_accuracy: 0.6536
# Epoch 4/10
# 1563/1563 - 8s - loss: 0.9131 - accuracy: 0.6797 - val_loss: 0.9477 - val_accuracy: 0.6665
# Epoch 5/10
# 1563/1563 - 7s - loss: 0.8383 - accuracy: 0.7061 - val_loss: 0.9464 - val_accuracy: 0.6706
# Epoch 6/10
# 1563/1563 - 8s - loss: 0.7780 - accuracy: 0.7258 - val_loss: 0.8951 - val_accuracy: 0.6849
# Epoch 7/10
# 1563/1563 - 7s - loss: 0.7359 - accuracy: 0.7434 - val_loss: 0.9169 - val_accuracy: 0.6878
# Epoch 8/10
# 1563/1563 - 8s - loss: 0.6890 - accuracy: 0.7573 - val_loss: 0.8597 - val_accuracy: 0.7040
# Epoch 9/10
# 1563/1563 - 7s - loss: 0.6556 - accuracy: 0.7702 - val_loss: 0.9034 - val_accuracy: 0.6942
# Epoch 10/10
# 1563/1563 - 7s - loss: 0.6169 - accuracy: 0.7826 - val_loss: 0.8746 - val_accuracy: 0.7112
# 313/313 [==============================] - 1s 4ms/step - loss: 0.8746 - accuracy: 0.7112
# 0.7111999988555908

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs,     acc )
plt.plot  ( epochs, val_acc )
plt.title ('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs,     loss )
plt.plot  ( epochs, val_loss )
plt.title ('Training and validation loss'   )
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# ## Image Augmentation

# %%
import tensorflow as tf


import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers, optimizers
import numpy as np
from matplotlib import pyplot



cifar10 = tf.keras.datasets.cifar10

num_classes = 10


(x_train, y_train), (x_test, y_test) = cifar10.load_data()


y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)


datagen_train = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

datagen_test = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)
# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)
datagen_train.fit(x_train)
datagen_test.fit(x_test)


# build the model

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(32, 32, 3)),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2, 2),  
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')

])


model.summary()


model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(datagen_train.flow(x_train, y_train),
         validation_data=datagen_test.flow(x_test, y_test),
         epochs=10)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 90,506
# Trainable params: 90,506
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1563/1563 [==============================] - 48s 30ms/step - loss: 1.6635 - accuracy: 0.3904 - val_loss: 1.4259 - val_accuracy: 0.4887
# Epoch 2/10
# 1563/1563 [==============================] - 47s 30ms/step - loss: 1.3651 - accuracy: 0.5092 - val_loss: 1.3677 - val_accuracy: 0.5278
# Epoch 3/10
# 1563/1563 [==============================] - 47s 30ms/step - loss: 1.2456 - accuracy: 0.5577 - val_loss: 1.1779 - val_accuracy: 0.5806
# Epoch 4/10
# 1563/1563 [==============================] - 47s 30ms/step - loss: 1.1749 - accuracy: 0.5877 - val_loss: 1.2406 - val_accuracy: 0.5823
# Epoch 5/10
# 1563/1563 [==============================] - 47s 30ms/step - loss: 1.1241 - accuracy: 0.6080 - val_loss: 1.0768 - val_accuracy: 0.6262
# Epoch 6/10
# 1563/1563 [==============================] - 47s 30ms/step - loss: 1.1001 - accuracy: 0.6204 - val_loss: 1.0853 - val_accuracy: 0.6241
# Epoch 7/10
# 1563/1563 [==============================] - 47s 30ms/step - loss: 1.0901 - accuracy: 0.6254 - val_loss: 1.1534 - val_accuracy: 0.6027
# Epoch 8/10
# 1563/1563 [==============================] - 47s 30ms/step - loss: 1.0886 - accuracy: 0.6246 - val_loss: 1.1466 - val_accuracy: 0.6189
# Epoch 9/10
# 1563/1563 [==============================] - 47s 30ms/step - loss: 1.0866 - accuracy: 0.6286 - val_loss: 1.1093 - val_accuracy: 0.6213
# Epoch 10/10
# 1563/1563 [==============================] - 47s 30ms/step - loss: 1.0933 - accuracy: 0.6254 - val_loss: 1.0879 - val_accuracy: 0.6263

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs,     acc )
plt.plot  ( epochs, val_acc )
plt.title ('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs,     loss )
plt.plot  ( epochs, val_loss )
plt.title ('Training and validation loss'   )
# Out:
# Text(0.5, 1.0, 'Training and validation loss')

# %% [markdown]
# # CIFAR-10 90%
#
# Vamos abordar o problema com ampliação, dropout, regularização, normalização de lote e 6 camadas convolucionais.

# %%
import tensorflow as tf


import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers, optimizers
import numpy as np
from matplotlib import pyplot



cifar10 = tf.keras.datasets.cifar10

num_classes = 10


(x_train, y_train), (x_test, y_test) = cifar10.load_data()


y_train = np_utils.to_categorical(y_train,num_classes)
y_test = np_utils.to_categorical(y_test,num_classes)

datagen_train = ImageDataGenerator(featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=True,
    zca_whitening=False,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False)


datagen_test = ImageDataGenerator(featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=True,
    zca_whitening=False,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False)


# compute quantities required for featurewise normalization
# (std, mean, and principal components if ZCA whitening is applied)
datagen_train.fit(x_train)
datagen_test.fit(x_test)

# build the model

# number of hidden units variable 
# we are declaring this variable here and use it in our CONV layers to make it easier to update from one place
base_hidden_units = 32

# l2 regularization hyperparameter
weight_decay = 1e-4 

# instantiate an empty sequential model 
model = Sequential()

# CONV1
# notice that we defined the input_shape here because this is the first CONV layer. 
# we don’t need to do that for the remaining layers
model.add(Conv2D(base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV2
model.add(Conv2D(base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# CONV3
model.add(Conv2D(2*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV4
model.add(Conv2D(2*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

# CONV5
model.add(Conv2D(4*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV6
model.add(Conv2D(4*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

# FC7
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))

# print model summary
model.summary()

opt = tf.keras.optimizers.RMSprop(learning_rate=0.0003, decay=1e-6)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

batch_size = 64
epochs=125

history = model.fit(datagen_train.flow(x_train, y_train,batch_size=batch_size),
         validation_data=datagen_test.flow(x_test, y_test), 
         steps_per_epoch=x_train.shape[0] / batch_size,
         epochs=epochs)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:356: UserWarning: This ImageDataGenerator specifies `samplewise_std_normalization`, which overrides setting of `samplewise_center`.
#   warnings.warn('This ImageDataGenerator specifies '
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                20490
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/125
# 781/781 [==============================] - 62s 76ms/step - loss: 2.1425 - accuracy: 0.3696 - val_loss: 1.5145 - val_accuracy: 0.5056
# Epoch 2/125
# 781/781 [==============================] - 59s 75ms/step - loss: 1.4920 - accuracy: 0.5193 - val_loss: 1.2370 - val_accuracy: 0.5871
# Epoch 3/125
# 781/781 [==============================] - 59s 75ms/step - loss: 1.2636 - accuracy: 0.5881 - val_loss: 1.1292 - val_accuracy: 0.6232
# Epoch 4/125
# 781/781 [==============================] - 60s 76ms/step - loss: 1.1151 - accuracy: 0.6343 - val_loss: 0.9745 - val_accuracy: 0.6884
# Epoch 5/125
# 781/781 [==============================] - 59s 76ms/step - loss: 1.0214 - accuracy: 0.6630 - val_loss: 0.8659 - val_accuracy: 0.7132
# Epoch 6/125
# 781/781 [==============================] - 59s 75ms/step - loss: 0.9500 - accuracy: 0.6884 - val_loss: 0.8844 - val_accuracy: 0.7066
# Epoch 7/125
# 781/781 [==============================] - 59s 75ms/step - loss: 0.9023 - accuracy: 0.7054 - val_loss: 0.8036 - val_accuracy: 0.7386
# Epoch 8/125
# 781/781 [==============================] - 59s 75ms/step - loss: 0.8556 - accuracy: 0.7208 - val_loss: 0.7832 - val_accuracy: 0.7478
# Epoch 9/125
# 781/781 [==============================] - 59s 76ms/step - loss: 0.8250 - accuracy: 0.7325 - val_loss: 0.7476 - val_accuracy: 0.7586
# Epoch 10/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.7958 - accuracy: 0.7418 - val_loss: 0.7442 - val_accuracy: 0.7613
# Epoch 11/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.7723 - accuracy: 0.7497 - val_loss: 0.7228 - val_accuracy: 0.7692
# Epoch 12/125
# 781/781 [==============================] - 60s 76ms/step - loss: 0.7520 - accuracy: 0.7588 - val_loss: 0.6809 - val_accuracy: 0.7821
# Epoch 13/125
# 781/781 [==============================] - 59s 76ms/step - loss: 0.7317 - accuracy: 0.7631 - val_loss: 0.6682 - val_accuracy: 0.7875
# Epoch 14/125
# 781/781 [==============================] - 59s 76ms/step - loss: 0.7162 - accuracy: 0.7706 - val_loss: 0.7491 - val_accuracy: 0.7658
# Epoch 15/125
# 781/781 [==============================] - 59s 76ms/step - loss: 0.7001 - accuracy: 0.7754 - val_loss: 0.6783 - val_accuracy: 0.7838
# Epoch 16/125
# 781/781 [==============================] - 59s 76ms/step - loss: 0.6874 - accuracy: 0.7785 - val_loss: 0.6260 - val_accuracy: 0.8046
# Epoch 17/125
# 781/781 [==============================] - 59s 76ms/step - loss: 0.6720 - accuracy: 0.7874 - val_loss: 0.6333 - val_accuracy: 0.8014
# Epoch 18/125
# 781/781 [==============================] - 59s 76ms/step - loss: 0.6601 - accuracy: 0.7909 - val_loss: 0.5934 - val_accuracy: 0.8117
# Epoch 19/125
# 781/781 [==============================] - 60s 76ms/step - loss: 0.6526 - accuracy: 0.7935 - val_loss: 0.6272 - val_accuracy: 0.8016
# Epoch 20/125
# 781/781 [==============================] - 60s 76ms/step - loss: 0.6448 - accuracy: 0.7959 - val_loss: 0.6257 - val_accuracy: 0.8086
# Epoch 21/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6330 - accuracy: 0.8006 - val_loss: 0.5805 - val_accuracy: 0.8188
# Epoch 22/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6276 - accuracy: 0.8041 - val_loss: 0.5972 - val_accuracy: 0.8126
# Epoch 23/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6148 - accuracy: 0.8061 - val_loss: 0.5981 - val_accuracy: 0.8140
# Epoch 24/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6089 - accuracy: 0.8103 - val_loss: 0.5700 - val_accuracy: 0.8259
# Epoch 25/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.6003 - accuracy: 0.8133 - val_loss: 0.5865 - val_accuracy: 0.8190
# Epoch 26/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5987 - accuracy: 0.8149 - val_loss: 0.5621 - val_accuracy: 0.8286
# Epoch 27/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5885 - accuracy: 0.8199 - val_loss: 0.5599 - val_accuracy: 0.8319
# Epoch 28/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5812 - accuracy: 0.8195 - val_loss: 0.5490 - val_accuracy: 0.8332
# Epoch 29/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5765 - accuracy: 0.8232 - val_loss: 0.5520 - val_accuracy: 0.8320
# Epoch 30/125
# 781/781 [==============================] - 60s 76ms/step - loss: 0.5781 - accuracy: 0.8220 - val_loss: 0.5347 - val_accuracy: 0.8344
# Epoch 31/125
# 781/781 [==============================] - 60s 76ms/step - loss: 0.5655 - accuracy: 0.8276 - val_loss: 0.5511 - val_accuracy: 0.8349
# Epoch 32/125
# 781/781 [==============================] - 60s 76ms/step - loss: 0.5644 - accuracy: 0.8287 - val_loss: 0.5465 - val_accuracy: 0.8350
# Epoch 33/125
# 781/781 [==============================] - 59s 76ms/step - loss: 0.5613 - accuracy: 0.8284 - val_loss: 0.5394 - val_accuracy: 0.8388
# Epoch 34/125
# 781/781 [==============================] - 60s 76ms/step - loss: 0.5568 - accuracy: 0.8299 - val_loss: 0.5494 - val_accuracy: 0.8324
# Epoch 35/125
# 781/781 [==============================] - 59s 76ms/step - loss: 0.5516 - accuracy: 0.8331 - val_loss: 0.5305 - val_accuracy: 0.8407
# Epoch 36/125
# 781/781 [==============================] - 59s 76ms/step - loss: 0.5497 - accuracy: 0.8344 - val_loss: 0.5296 - val_accuracy: 0.8441
# Epoch 37/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5410 - accuracy: 0.8367 - val_loss: 0.5320 - val_accuracy: 0.8459
# Epoch 38/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5361 - accuracy: 0.8372 - val_loss: 0.5319 - val_accuracy: 0.8393
# Epoch 39/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5359 - accuracy: 0.8394 - val_loss: 0.5378 - val_accuracy: 0.8404
# Epoch 40/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5362 - accuracy: 0.8365 - val_loss: 0.5329 - val_accuracy: 0.8409
# Epoch 41/125
# 781/781 [==============================] - 60s 76ms/step - loss: 0.5324 - accuracy: 0.8395 - val_loss: 0.5126 - val_accuracy: 0.8458
# Epoch 42/125
# 781/781 [==============================] - 60s 76ms/step - loss: 0.5331 - accuracy: 0.8409 - val_loss: 0.5312 - val_accuracy: 0.8402
# Epoch 43/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5225 - accuracy: 0.8432 - val_loss: 0.5291 - val_accuracy: 0.8472
# Epoch 44/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5257 - accuracy: 0.8420 - val_loss: 0.5119 - val_accuracy: 0.8494
# Epoch 45/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5256 - accuracy: 0.8428 - val_loss: 0.5227 - val_accuracy: 0.8386
# Epoch 46/125
# 781/781 [==============================] - 60s 76ms/step - loss: 0.5168 - accuracy: 0.8445 - val_loss: 0.5078 - val_accuracy: 0.8508
# Epoch 47/125
# 781/781 [==============================] - 60s 76ms/step - loss: 0.5180 - accuracy: 0.8466 - val_loss: 0.5055 - val_accuracy: 0.8495
# Epoch 48/125
# 781/781 [==============================] - 59s 76ms/step - loss: 0.5139 - accuracy: 0.8475 - val_loss: 0.5209 - val_accuracy: 0.8477
# Epoch 49/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5086 - accuracy: 0.8483 - val_loss: 0.5017 - val_accuracy: 0.8498
# Epoch 50/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5042 - accuracy: 0.8493 - val_loss: 0.5008 - val_accuracy: 0.8544
# Epoch 51/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5102 - accuracy: 0.8486 - val_loss: 0.4949 - val_accuracy: 0.8551
# Epoch 52/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5052 - accuracy: 0.8494 - val_loss: 0.5152 - val_accuracy: 0.8451
# Epoch 53/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.5056 - accuracy: 0.8504 - val_loss: 0.4903 - val_accuracy: 0.8562
# Epoch 54/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4928 - accuracy: 0.8543 - val_loss: 0.5021 - val_accuracy: 0.8557
# Epoch 55/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4955 - accuracy: 0.8543 - val_loss: 0.5154 - val_accuracy: 0.8503
# Epoch 56/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4886 - accuracy: 0.8558 - val_loss: 0.5023 - val_accuracy: 0.8536
# Epoch 57/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4957 - accuracy: 0.8551 - val_loss: 0.4979 - val_accuracy: 0.8524
# Epoch 58/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4921 - accuracy: 0.8546 - val_loss: 0.4893 - val_accuracy: 0.8564
# Epoch 59/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4914 - accuracy: 0.8562 - val_loss: 0.4900 - val_accuracy: 0.8592
# Epoch 60/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4907 - accuracy: 0.8546 - val_loss: 0.4851 - val_accuracy: 0.8578
# Epoch 61/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4864 - accuracy: 0.8572 - val_loss: 0.4895 - val_accuracy: 0.8579
# Epoch 62/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4847 - accuracy: 0.8566 - val_loss: 0.5029 - val_accuracy: 0.8550
# Epoch 63/125
# 781/781 [==============================] - 61s 77ms/step - loss: 0.4825 - accuracy: 0.8584 - val_loss: 0.5010 - val_accuracy: 0.8554
# Epoch 64/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4820 - accuracy: 0.8599 - val_loss: 0.4855 - val_accuracy: 0.8602
# Epoch 65/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4784 - accuracy: 0.8606 - val_loss: 0.4838 - val_accuracy: 0.8617
# Epoch 66/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4760 - accuracy: 0.8614 - val_loss: 0.4848 - val_accuracy: 0.8583
# Epoch 67/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4748 - accuracy: 0.8620 - val_loss: 0.4914 - val_accuracy: 0.8603
# Epoch 68/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4741 - accuracy: 0.8609 - val_loss: 0.4762 - val_accuracy: 0.8627
# Epoch 69/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4731 - accuracy: 0.8628 - val_loss: 0.4755 - val_accuracy: 0.8612
# Epoch 70/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4743 - accuracy: 0.8617 - val_loss: 0.4962 - val_accuracy: 0.8611
# Epoch 71/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4730 - accuracy: 0.8610 - val_loss: 0.4859 - val_accuracy: 0.8584
# Epoch 72/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4663 - accuracy: 0.8646 - val_loss: 0.4910 - val_accuracy: 0.8594
# Epoch 73/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4678 - accuracy: 0.8643 - val_loss: 0.4916 - val_accuracy: 0.8602
# Epoch 74/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4657 - accuracy: 0.8664 - val_loss: 0.4816 - val_accuracy: 0.8625
# Epoch 75/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4691 - accuracy: 0.8656 - val_loss: 0.4783 - val_accuracy: 0.8627
# Epoch 76/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4670 - accuracy: 0.8656 - val_loss: 0.4991 - val_accuracy: 0.8556
# Epoch 77/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4631 - accuracy: 0.8663 - val_loss: 0.4818 - val_accuracy: 0.8643
# Epoch 78/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4643 - accuracy: 0.8664 - val_loss: 0.4761 - val_accuracy: 0.8641
# Epoch 79/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4613 - accuracy: 0.8669 - val_loss: 0.4691 - val_accuracy: 0.8681
# Epoch 80/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4540 - accuracy: 0.8691 - val_loss: 0.4906 - val_accuracy: 0.8620
# Epoch 81/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4606 - accuracy: 0.8683 - val_loss: 0.4691 - val_accuracy: 0.8664
# Epoch 82/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4543 - accuracy: 0.8689 - val_loss: 0.4864 - val_accuracy: 0.8620
# Epoch 83/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4557 - accuracy: 0.8703 - val_loss: 0.4686 - val_accuracy: 0.8701
# Epoch 84/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4540 - accuracy: 0.8700 - val_loss: 0.4765 - val_accuracy: 0.8652
# Epoch 85/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4531 - accuracy: 0.8692 - val_loss: 0.4964 - val_accuracy: 0.8588
# Epoch 86/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4575 - accuracy: 0.8682 - val_loss: 0.4799 - val_accuracy: 0.8610
# Epoch 87/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4499 - accuracy: 0.8704 - val_loss: 0.4734 - val_accuracy: 0.8707
# Epoch 88/125
# 781/781 [==============================] - 61s 77ms/step - loss: 0.4504 - accuracy: 0.8719 - val_loss: 0.4803 - val_accuracy: 0.8666
# Epoch 89/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4533 - accuracy: 0.8697 - val_loss: 0.4728 - val_accuracy: 0.8663
# Epoch 90/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4484 - accuracy: 0.8725 - val_loss: 0.4594 - val_accuracy: 0.8707
# Epoch 91/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4508 - accuracy: 0.8707 - val_loss: 0.4662 - val_accuracy: 0.8706
# Epoch 92/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4440 - accuracy: 0.8749 - val_loss: 0.4670 - val_accuracy: 0.8686
# Epoch 93/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4473 - accuracy: 0.8734 - val_loss: 0.4625 - val_accuracy: 0.8707
# Epoch 94/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4417 - accuracy: 0.8750 - val_loss: 0.4664 - val_accuracy: 0.8701
# Epoch 95/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4451 - accuracy: 0.8731 - val_loss: 0.4661 - val_accuracy: 0.8678
# Epoch 96/125
# 781/781 [==============================] - 60s 77ms/step - loss: 0.4463 - accuracy: 0.8739 - val_loss: 0.4782 - val_accuracy: 0.8675
# Epoch 97/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4384 - accuracy: 0.8754 - val_loss: 0.4669 - val_accuracy: 0.8687
# Epoch 98/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4459 - accuracy: 0.8736 - val_loss: 0.4546 - val_accuracy: 0.8727
# Epoch 99/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4365 - accuracy: 0.8759 - val_loss: 0.4778 - val_accuracy: 0.8650
# Epoch 100/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4397 - accuracy: 0.8738 - val_loss: 0.4682 - val_accuracy: 0.8726
# Epoch 101/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4310 - accuracy: 0.8782 - val_loss: 0.4660 - val_accuracy: 0.8698
# Epoch 102/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4389 - accuracy: 0.8758 - val_loss: 0.4711 - val_accuracy: 0.8698
# Epoch 103/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4380 - accuracy: 0.8758 - val_loss: 0.4592 - val_accuracy: 0.8713
# Epoch 104/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4344 - accuracy: 0.8783 - val_loss: 0.4492 - val_accuracy: 0.8732
# Epoch 105/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4344 - accuracy: 0.8762 - val_loss: 0.4627 - val_accuracy: 0.8723
# Epoch 106/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4342 - accuracy: 0.8768 - val_loss: 0.4748 - val_accuracy: 0.8672
# Epoch 107/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4335 - accuracy: 0.8775 - val_loss: 0.4645 - val_accuracy: 0.8726
# Epoch 108/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4348 - accuracy: 0.8775 - val_loss: 0.4601 - val_accuracy: 0.8719
# Epoch 109/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4313 - accuracy: 0.8783 - val_loss: 0.4540 - val_accuracy: 0.8739
# Epoch 110/125
# 781/781 [==============================] - 61s 77ms/step - loss: 0.4342 - accuracy: 0.8777 - val_loss: 0.4538 - val_accuracy: 0.8744
# Epoch 111/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4323 - accuracy: 0.8786 - val_loss: 0.4495 - val_accuracy: 0.8731
# Epoch 112/125
# 781/781 [==============================] - 61s 79ms/step - loss: 0.4326 - accuracy: 0.8781 - val_loss: 0.4571 - val_accuracy: 0.8706
# Epoch 113/125
# 781/781 [==============================] - 61s 78ms/step - loss: 0.4278 - accuracy: 0.8799 - val_loss: 0.4527 - val_accuracy: 0.8737
# Epoch 114/125
# 781/781 [==============================] - 62s 79ms/step - loss: 0.4277 - accuracy: 0.8794 - val_loss: 0.4635 - val_accuracy: 0.8731
# Epoch 115/125
# 781/781 [==============================] - 62s 79ms/step - loss: 0.4253 - accuracy: 0.8806 - val_loss: 0.4539 - val_accuracy: 0.8763
# Epoch 116/125
# 781/781 [==============================] - 62s 79ms/step - loss: 0.4261 - accuracy: 0.8808 - val_loss: 0.4526 - val_accuracy: 0.8792
# Epoch 117/125
# 781/781 [==============================] - 62s 79ms/step - loss: 0.4269 - accuracy: 0.8797 - val_loss: 0.4581 - val_accuracy: 0.8748
# Epoch 118/125
# 781/781 [==============================] - 62s 79ms/step - loss: 0.4231 - accuracy: 0.8817 - val_loss: 0.4756 - val_accuracy: 0.8686
# Epoch 119/125
# 781/781 [==============================] - 62s 79ms/step - loss: 0.4302 - accuracy: 0.8782 - val_loss: 0.4433 - val_accuracy: 0.8756
# Epoch 120/125
# 781/781 [==============================] - 62s 79ms/step - loss: 0.4253 - accuracy: 0.8802 - val_loss: 0.4554 - val_accuracy: 0.8738
# Epoch 121/125
# 781/781 [==============================] - 62s 79ms/step - loss: 0.4236 - accuracy: 0.8818 - val_loss: 0.4566 - val_accuracy: 0.8720
# Epoch 122/125
# 781/781 [==============================] - 62s 79ms/step - loss: 0.4230 - accuracy: 0.8821 - val_loss: 0.4587 - val_accuracy: 0.8711
# Epoch 123/125
# 781/781 [==============================] - 62s 79ms/step - loss: 0.4256 - accuracy: 0.8808 - val_loss: 0.4652 - val_accuracy: 0.8711
# Epoch 124/125
# 781/781 [==============================] - 62s 79ms/step - loss: 0.4251 - accuracy: 0.8803 - val_loss: 0.4569 - val_accuracy: 0.8741
# Epoch 125/125
# 781/781 [==============================] - 62s 79ms/step - loss: 0.4214 - accuracy: 0.8820 - val_loss: 0.4326 - val_accuracy: 0.8837
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d7c59c2e58b7> in <module>()
#     138 # Plot training and validation accuracy per epoch
#     139 #------------------------------------------------
# --> 140 plt.plot  ( epochs,     acc )
#     141 plt.plot  ( epochs, val_acc )
#     142 plt.title ('Training and validation accuracy')
#
# NameError: name 'plt' is not defined

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc      = history.history[     'accuracy' ]
val_acc  = history.history[ 'val_accuracy' ]
loss     = history.history[    'loss' ]
val_loss = history.history['val_loss' ]

epochs   = range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot  ( epochs,     acc )
plt.plot  ( epochs, val_acc )
plt.title ('Training and validation accuracy')
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot  ( epochs,     loss )
plt.plot  ( epochs, val_loss )
plt.title ('Training and validation loss'   )

model.save_weights("weights.h5")
# Out:
# Text(0.5, 1.0, 'Training and validation loss')
