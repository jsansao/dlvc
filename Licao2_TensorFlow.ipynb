# %% [markdown]
# <a href="https://colab.research.google.com/github/jsansao/dlvc/blob/main/Licao2_TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##### Copyright 2019 The TensorFlow Authors.

# %% [markdown]
# Esse notebook foi adaptado de [https://github.com/lmoroney/dlaicourse](https://github.com/lmoroney/dlaicourse)

# %%
#@title Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
# https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# # Hello World do Deep Learning com redes neurais

# %% [markdown]
# O primeiro exemplo de utilização do TensorFlow é aproximar uma função matemática conhecida, a partir de pares (x,y).
#
# A função é dada por: y = 2x -1

# %% [markdown]
# ## Bibliotecas necessárias
#
# * Vamos importar ``tensorflow`` como ``tf``;
# * ``numpy`` como ``np`` para representar os dados como listas facilmente e rapidamente;
# * Vamos usar o framework ``keras`` para definir a rede neural como um conjunto de camadas seqüenciais.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# ## Definindo e compilando a rede neural
#
# Vamos criar o modelo mais simples de rede neural. Apenas 1 camada, essa camada tem 1 neurônio e uma entrada.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# Além do modelo, deve-se definir duas funções: a função de perda (``loss``) e otimizador (``optimizer``).
#
# A função de perda avalia o erro na aproximação do modelo. O ajuste é feito iterativamente e otimizador sugere os passos seguintes de modo a minimizar a função de perda.
#
# A iterações são denominadas épocas (EPOCHS). No exemplo, utilizaremos a função de perda de erro quadrático médio ('MEAN SQUARED ERROR') e como otimizador o gradiente descendente estocástico ('STOCHASTIC GRADIENT DESCENT').

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ## Fornecendo os dados
#
#
# Forneceremos alguns pares (x,y) gerados com a função original (y=2x-1).
#
# Utilizaremos a ``numpy`` para entrada dos dados como arranjos numéricos.

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# # Treinando a rede neural

# %% [markdown]
# O processo de "aprendizado" da rede neural é feito utilizando o comando ``model.fit``. Neste caso, limitou-se a 500 epochs para o ajuste. Cada época retorna o valor da função de perda avaliada.

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 514ms/step - loss: 12.3276
# Epoch 2/500
# 1/1 [==============================] - 0s 9ms/step - loss: 9.9238
# Epoch 3/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.0279
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 6.5318
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.3504
# Epoch 6/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.4165
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 3.6775
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 3.0920
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.6272
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.2575
# Epoch 11/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.9628
# Epoch 12/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.7271
# ...

# %% [markdown]
# A função ``model.predict`` pode ser usada para testar o modelo ajustado com valores arbitrários. Testando para 0, 5, 10 teremos os seguintes resultados:

# %%
print(model.predict([0, 5, 10.0]))
# Out:
# [[-0.9920132]
#  [ 8.995107 ]
#  [18.982225 ]]

# %% [markdown]
# Note que as respostas não são exatas (-1, 9 e 19).
